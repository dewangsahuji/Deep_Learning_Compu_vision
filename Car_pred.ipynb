# %% [markdown]
# <a href="https://colab.research.google.com/github/dewangsahuji/Deep_Learning_Compu_vision/blob/Car_pred/Car_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Car Prediction**

# %% [markdown]
# ## Task
# ### To Predict the price of Cars

# %%
# Install dependencies if needed:
# pip install kagglehub[hf-datasets]

import kagglehub
from kagglehub import KaggleDatasetAdapter

# Provide a specific file name if desired, else use None or omit it
file_name = "train.csv"  # or "your_filename.csv" if you know it

hf_dataset = kagglehub.dataset_load(
    KaggleDatasetAdapter.HUGGING_FACE,
    "mayankpatel14/second-hand-used-cars-data-set-linear-regression",
    file_name  # positional — not as named argument
)

print("Loaded Hugging Face Dataset:", hf_dataset)

# To convert to pandas DataFrame:
df = hf_dataset.to_pandas()
print(df.head())
# Out:
# Loaded Hugging Face Dataset: Dataset({
#     features: ['v.id', 'on road old', 'on road now', 'years', 'km', 'rating', 'condition', 'economy', 'top speed', 'hp', 'torque', 'current price'],
#     num_rows: 1000
# })
#    v.id  on road old  on road now  years      km  rating  condition  economy  \
# 0     1       535651       798186      3   78945       1          2       14
# 1     2       591911       861056      6  117220       5          9        9
# 2     3       686990       770762      2  132538       2          8       15
# 3     4       573999       722381      4  101065       4          3       11
# 4     5       691388       811335      6   61559       3          9       12
#
#    top speed  hp  torque  current price
# 0        177  73     123       351318.0
# 1        148  74      95       285001.5
# 2        181  53      97       215386.0
# 3        197  54     116       244295.5
# 4        160  53     105       531114.5
